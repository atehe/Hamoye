# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
energy_data = pd.read_csv(r"C:\Users\PHOSI\Downloads\energydata_complete.csv", error_bad_lines=False)
energy_data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy_data.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
energy_data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
ml_data = energy_data.drop(columns=["date"])
ml_data
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
corr_df = ml_data.corr()
corr_df[corr_df["T2"]>=0.7]
# Out:
#        Appliances    lights        T1      RH_1        T2      RH_2        T3  \
# T1       0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509  0.892402
# T2       0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610  0.735245
# T3       0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319  1.000000
# T4       0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304  0.852778
# T5       0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409  0.888169
# T6       0.117638 -0.079029  0.654769  0.316141  0.801186 -0.009670  0.686882
# T_out    0.099155 -0.074424  0.682846  0.340767  0.792255  0.033674  0.699417
#
#            RH_3        T4      RH_4  ...        T9      RH_9     T_out  \
# T1    -0.028550  0.877001  0.097861  ...  0.844777  0.071756  0.682846
# T2     0.121497  0.762066  0.231563  ...  0.675535  0.157346  0.792255
# T3    -0.011234  0.852778  0.122737  ...  0.901324  0.134602  0.699417
# ...

# %%
# LINEAR MODEL T2 AND T6
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_df = pd.DataFrame(scaler.fit_transform(ml_data), columns=ml_data.columns)

predictor = normalized_df.drop(columns=["T1","T4", "T3",'T6', "T5", "T_out"])
response = normalized_df['T6']


from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(predictor, response, test_size=0.3, random_state=2)

from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression()

model.fit(x_train, y_train)
predicted_val = model.predict(x_test)

# %%
# R-squared value
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
rsquared = r2_score(y_test, predicted_val)
round(rsquared, 2)
# Out:
# 0.96

# %%
# Mean Absolute Error
mae = mean_absolute_error(y_test, predicted_val)
round(mae, 2)
# Out:
# 0.03

# %%
# Residual Sum of Squares
rss= np.sum(np.square(y_test - predicted_val)) 
round(rss, 3)
# Out:
# 7.829

# %%
# Root Mean Square Error
rmse=np.sqrt(mean_squared_error(y_test, predicted_val))
round(rmse, 3)
# Out:
# 0.036

# %%
# RIDGE REGRESSION
ridge = Ridge(alpha=0.001)
ridge.fit(x_train, y_train)
ridge.coef_
# Out:
# array([ 2.63627727e-02, -5.85439317e-03,  1.09914586e-01,  1.00876515e-01,
#        -1.57150797e-01, -8.61860624e-02,  4.92389762e-02, -1.85769810e-02,
#        -7.77351859e-02, -7.55599040e-02,  4.20907525e-03, -1.01052567e-01,
#        -3.73394521e-02,  7.09059434e-02,  4.09515621e-02, -3.46710628e-02,
#        -3.97177038e-01, -2.70301565e-02,  4.72272424e-03,  6.70604252e-01,
#         2.92519496e-06,  2.92516809e-06])

# %%
ridge_val = ridge.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test, ridge_val))
round(rmse, 3)
# Out:
# 0.036

# %%
# LASSO REGRESSION
lasso = Lasso(alpha=0.001)
lasso.fit(x_train, y_train)
lasso.coef_
# Out:
# array([ 0.        , -0.        ,  0.        ,  0.09988838, -0.        ,
#         0.        ,  0.        , -0.        , -0.06948487, -0.        ,
#         0.        , -0.01305591,  0.        , -0.        ,  0.        ,
#        -0.        , -0.39132711,  0.        ,  0.        ,  0.62542502,
#        -0.        , -0.        ])

# %%
lasso_val = lasso.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test, lasso_val))
round(rmse, 3)
# Out:
# 0.041
